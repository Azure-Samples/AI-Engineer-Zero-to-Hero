# %% [markdown]
# # Lab 16: Evaluate Your Generative AI Application
#
# > ⚠️ **In Development**: This notebook is still being developed and is not ready for use yet. Content and APIs may change significantly.
#
# Use the **Azure AI Evaluation SDK** to assess the quality and safety of your AI applications!
#
#
# ## What is Azure AI Evaluation?
#
# | Challenge | Solution |
# |-----------|----------|
# | How good are my agent's responses? | **Quality evaluators** (coherence, fluency, relevance) |
# | Are responses grounded in facts? | **Groundedness evaluators** detect hallucinations |
# | Is my agent safe to deploy? | **Safety evaluators** check for harmful content |
# | How do I measure at scale? | **Batch evaluation** with `evaluate()` API |
#
# ## Features Demonstrated
#
# - **Built-in Evaluators** - Quality metrics (coherence, fluency, relevance, groundedness)
# - **Custom Evaluators** - Create your own evaluation logic
# - **Batch Evaluation** - Run evaluators on entire test datasets
# - **Agent Evaluation** - Test the Space Expert agent from Lab 6
#
# ## Prerequisites
#
# - Completed **Lab 1a** (Landing Zone with APIM)
# - Completed **Lab 6** (Foundry IQ - Space Expert Agent)
# - `.env` file with APIM_URL and APIM_KEY

# %% [markdown]
# ## Step 1: Install Dependencies

# %%
# !pip install azure-ai-evaluation azure-ai-projects azure-identity pandas requests -q

# %% [markdown]
# ## Step 2: Configure Variables
#
# Load configuration from the parent `.env` file and Lab 6's deployment.

# %%
import subprocess
import os
import json
from pathlib import Path
from IPython.display import display, Markdown

# Load .env from parent directory
env_path = Path("../.env")
if env_path.exists():
    for line in env_path.read_text().splitlines():
        if '=' in line and not line.startswith('#'):
            key, value = line.split('=', 1)
            os.environ[key.strip()] = value.strip()

# Landing Zone settings (from Lab 1a)
APIM_URL = os.environ.get("APIM_URL", "")
APIM_KEY = os.environ.get("APIM_KEY", "")
MODEL_NAME = os.environ.get("MODEL_NAME", "gpt-4.1-mini")

# Lab 6 resource group
RG = "lab06-foundry-iq"

# Get subscription ID
SUBSCRIPTION_ID = subprocess.run(
    'az account show --query id -o tsv',
    shell=True, capture_output=True, text=True
).stdout.strip()

# Verify configuration
if not APIM_URL or not APIM_KEY:
    print("❌ Missing APIM_URL or APIM_KEY in .env file!")
    print("   Please complete Lab 1a first")
else:
    display(Markdown(f'''
### ✅ Configuration Loaded

| Setting | Value |
|---------|-------|
| APIM Gateway | `{APIM_URL[:50]}...` |
| Evaluator Model | `{MODEL_NAME}` |
| Resource Group | `{RG}` |
'''))
# Out:
# ### ✅ Configuration Loaded
#
# | Setting | Value |
# |---------|-------|
# | APIM Gateway | `https://foundry-apim-ewkh6p.azure-api.net/openai...` |
# | Evaluator Model | `gpt-4.1-mini` |
# | Resource Group | `foundryiq-lab` |

# %% [markdown]
# ## Step 3: Load Lab 6 Deployment Info
#
# Get the Foundry IQ project details from Lab 6.

# %%
# Get deployment outputs from Lab 6
try:
    outputs = json.loads(subprocess.run(
        f'az deployment group show -g "{RG}" -n spoke --query properties.outputs -o json',
        shell=True, capture_output=True, text=True
    ).stdout)

    PROJECT_ENDPOINT = outputs['projectEndpoint']['value']
    APIM_CONNECTION = outputs['apimConnectionName']['value']
    SEARCH_ENDPOINT = outputs['searchEndpoint']['value']
    GATEWAY_MODEL = f"{APIM_CONNECTION}/{outputs['gatewayModelName']['value']}"
    KNOWLEDGE_BASE = "space-facts-kb"

    display(Markdown(f'''
### ✅ Lab 6 Resources Found

| Resource | Value |
|----------|-------|
| Project Endpoint | `{PROJECT_ENDPOINT[:50]}...` |
| Gateway Model | `{GATEWAY_MODEL}` |
| Knowledge Base | `{KNOWLEDGE_BASE}` |
'''))
except Exception as e:
    print(f"❌ Could not load Lab 6 deployment: {e}")
    print("   Please complete Lab 6 first!")
# Out:
# ### ✅ Lab 6 Resources Found
#
# | Resource | Value |
# |----------|-------|
# | Project Endpoint | `https://iq-spoke-56xhkm.services.ai.azure.com/api/...` |
# | Gateway Model | `landing-zone-apim/gpt-4.1-mini` |
# | Knowledge Base | `space-facts-kb` |

# %% [markdown]
# ## Step 4: Set Up Model Configuration for Evaluators
#
# AI-assisted evaluators need a model to act as a "judge". We'll use the APIM gateway.

# %%
import subprocess, json

# Lab 6 resource group
RG = "lab06-foundry-iq"

# Get AI Services account
result = subprocess.run(f'az cognitiveservices account list -g "{RG}" --query "[0].name" -o tsv', shell=True, capture_output=True, text=True)
ACCOUNT = result.stdout.strip()
print(f"Account: {ACCOUNT}")
# Out:
# ✅ Model configuration ready!
#    Using: gpt-4.1-mini via APIM gateway

# %% [markdown]
# ## Step 5: Connect to Space Expert Agent
#
# Connect to the agent we created in Lab 6.

# %%
from azure.ai.projects import AIProjectClient
from azure.identity import DefaultAzureCredential

credential = DefaultAzureCredential()
project_client = AIProjectClient(endpoint=PROJECT_ENDPOINT, credential=credential)
openai_client = project_client.get_openai_client()

# Get the Space Expert agent
AGENT_NAME = "SpaceExpert"
agent = project_client.agents.get(agent_name=AGENT_NAME)
agent_version = agent.versions.latest.version

print(f"✅ Connected to agent: {agent.name} v{agent_version}")

def ask_space_expert(question: str) -> str:
    """Ask the space expert a question."""
    response = openai_client.responses.create(
        input=question,
        extra_body={
            "agent": {
                "name": agent.name, 
                "version": agent_version, 
                "type": "agent_reference"
            }
        }
    )
    return response.output_text

# Test the connection
test_response = ask_space_expert("What is the Apollo 14 mission?")
print(f"\n📡 Test response: {test_response[:200]}...")
# Out:
# ✅ Connected to agent: SpaceExpert v1
#
# 📡 Test response: I don't know....

# %% [markdown]
# ## Step 6: Create Test Dataset
#
# We'll create a test dataset based on our space facts, with queries, expected answers (ground truth), and context.

# %%
import pandas as pd

# Test dataset with queries, ground truth, and context
test_data = [
    {
        "query": "What is the largest volcano in the solar system?",
        "ground_truth": "Olympus Mons on Mars is the largest volcano in the solar system, about 13.6 miles high.",
        "context": "Mars has the largest volcano in the solar system called Olympus Mons which is about 13.6 miles high."
    },
    {
        "query": "How long has Jupiter's Great Red Spot been active?",
        "ground_truth": "Jupiter's Great Red Spot has been raging for over 400 years.",
        "context": "Jupiter's Great Red Spot is a storm that has been raging for over 400 years and is so big that Earth could fit inside it."
    },
    {
        "query": "Why is a day on Venus longer than its year?",
        "ground_truth": "Venus takes 243 Earth days to rotate once but only 225 Earth days to orbit the Sun, making its day longer than its year.",
        "context": "A day on Venus is longer than its year! Venus takes 243 Earth days to rotate once but only 225 Earth days to orbit the Sun."
    },
    {
        "query": "How much of the solar system's mass does the Sun contain?",
        "ground_truth": "The Sun contains 99.86% of all mass in our solar system.",
        "context": "The Sun contains 99.86% of all mass in our solar system."
    },
    {
        "query": "How fast does the International Space Station travel?",
        "ground_truth": "The ISS travels at about 17,500 mph and completes one orbit every 90 minutes.",
        "context": "The International Space Station travels at about 17500 mph completing one orbit around Earth every 90 minutes."
    },
    {
        "query": "What happens to astronauts' height in space?",
        "ground_truth": "Astronauts grow up to 2 inches taller in space because there is no gravity compressing their spines.",
        "context": "Astronauts grow up to 2 inches taller in space because there is no gravity compressing their spines."
    }
]

df_test = pd.DataFrame(test_data)
display(Markdown("### 📋 Test Dataset"))
display(df_test[['query', 'ground_truth']])
# Out:
# ### 📋 Test Dataset
#                                                query  \
# 0   What is the largest volcano in the solar system?
# 1  How long has Jupiter's Great Red Spot been act...
# 2        Why is a day on Venus longer than its year?
# 3  How much of the solar system's mass does the S...
# 4  How fast does the International Space Station ...
# 5       What happens to astronauts' height in space?
#
#                                         ground_truth
# 0  Olympus Mons on Mars is the largest volcano in...
# 1  Jupiter's Great Red Spot has been raging for o...
# 2  Venus takes 243 Earth days to rotate once but ...
# 3  The Sun contains 99.86% of all mass in our sol...
# 4  The ISS travels at about 17,500 mph and comple...
# 5  Astronauts grow up to 2 inches taller in space...

# %% [markdown]
# ## Step 7: Generate Agent Responses
#
# Run the test queries through our Space Expert agent to get responses.

# %%
print("🤖 Generating agent responses...")
responses = []

for i, row in df_test.iterrows():
    print(f"  Query {i+1}/{len(df_test)}: {row['query'][:50]}...")
    response = ask_space_expert(row['query'])
    responses.append(response)

df_test['response'] = responses

print("\n✅ All responses generated!")
display(Markdown("### Sample Response"))
display(Markdown(f"**Query:** {df_test.iloc[0]['query']}"))
display(Markdown(f"**Response:** {df_test.iloc[0]['response']}"))
# Out:
# 🤖 Generating agent responses...
#   Query 1/6: What is the largest volcano in the solar system?...
#   Query 2/6: How long has Jupiter's Great Red Spot been active?...
#   Query 3/6: Why is a day on Venus longer than its year?...
#   Query 4/6: How much of the solar system's mass does the Sun c...
#   Query 5/6: How fast does the International Space Station trav...
#   Query 6/6: What happens to astronauts' height in space?...
#
# ✅ All responses generated!
# ### Sample Response
# **Query:** What is the largest volcano in the solar system?
# **Response:** The largest volcano in the solar system is Olympus Mons on Mars. It stands about 13.6 miles (22 kilometers) high, making it the tallest volcano known in the solar system. (Source: fact-010)

# %% [markdown]
# ## Step 8: Save Test Data as JSONL
#
# The `evaluate()` API expects data in JSONL format.

# %%
# Save test data to JSONL
df_test.to_json('test_data.jsonl', orient='records', lines=True)
print("✅ Test data saved to test_data.jsonl")

# Show sample line
with open('test_data.jsonl', 'r') as f:
    first_line = json.loads(f.readline())
    print("\n📄 Sample JSONL entry:")
    print(json.dumps(first_line, indent=2)[:500] + "...")
# Out:
# ✅ Test data saved to test_data.jsonl
#
# 📄 Sample JSONL entry:
# {
#   "query": "What is the largest volcano in the solar system?",
#   "ground_truth": "Olympus Mons on Mars is the largest volcano in the solar system, about 13.6 miles high.",
#   "context": "Mars has the largest volcano in the solar system called Olympus Mons which is about 13.6 miles high.",
#   "response": "The largest volcano in the solar system is Olympus Mons on Mars. It stands about 13.6 miles (22 kilometers) high, making it the tallest volcano known in the solar system. (Source: fact-010)"
# }...

# %% [markdown]
# ---
# # Part 2: Single-Row Evaluation (Spot Check)
#
# Before running batch evaluation, let's test individual evaluators on a single row.

# %% [markdown]
# ## Step 9: Quality Evaluators - Coherence & Fluency
#
# These evaluators assess how well-written and readable the responses are.

# %%
from azure.ai.evaluation import CoherenceEvaluator, FluencyEvaluator

# Initialize evaluators
coherence_eval = CoherenceEvaluator(model_config)
fluency_eval = FluencyEvaluator(model_config)

# Test on first sample
sample = df_test.iloc[0]

coherence_result = coherence_eval(
    query=sample['query'],
    response=sample['response']
)

fluency_result = fluency_eval(
    query=sample['query'],
    response=sample['response']
)

display(Markdown(f'''
### 🎯 Single-Row Quality Evaluation

**Query:** {sample['query']}

**Response:** {sample['response'][:200]}...

| Metric | Score | Reason |
|--------|-------|--------|
| **Coherence** | {coherence_result.get('coherence', 'N/A')} | {coherence_result.get('coherence_reason', 'N/A')[:100]}... |
| **Fluency** | {fluency_result.get('fluency', 'N/A')} | {fluency_result.get('fluency_reason', 'N/A')[:100]}... |
'''))
# Out:
# ### 🎯 Single-Row Quality Evaluation
#
# **Query:** What is the largest volcano in the solar system?
#
# **Response:** The largest volcano in the solar system is Olympus Mons on Mars. It stands about 13.6 miles (22 kilometers) high, making it the tallest volcano known in the solar system. (Source: fact-010)...
#
# | Metric | Score | Reason |
# |--------|-------|--------|
# | **Coherence** | 4.0 | The response is coherent because it directly addresses the question with clear, logically ordered in... |
# | **Fluency** | 3.0 | The response is clear, coherent, and grammatically correct with adequate vocabulary and sentence str... |

# %% [markdown]
# ## Step 10: Relevance Evaluator
#
# Does the response actually answer the question?

# %%
from azure.ai.evaluation import RelevanceEvaluator

relevance_eval = RelevanceEvaluator(model_config)

relevance_result = relevance_eval(
    query=sample['query'],
    response=sample['response']
)

display(Markdown(f'''
### 🎯 Relevance Evaluation

| Metric | Score |
|--------|-------|
| **Relevance** | {relevance_result.get('relevance', 'N/A')} |

**Reason:** {relevance_result.get('relevance_reason', 'N/A')}
'''))
# Out:
# ### 🎯 Relevance Evaluation
#
# | Metric | Score |
# |--------|-------|
# | **Relevance** | 4.0 |
#
# **Reason:** The response directly answers the user's question by naming Olympus Mons as the largest volcano in the solar system and provides specific details about its height, fully addressing the query with accurate and relevant information.

# %% [markdown]
# ## Step 11: Groundedness Evaluator
#
# Is the response grounded in the provided context? This detects hallucinations!

# %%
from azure.ai.evaluation import GroundednessEvaluator

groundedness_eval = GroundednessEvaluator(model_config)

groundedness_result = groundedness_eval(
    query=sample['query'],
    context=sample['context'],
    response=sample['response']
)

display(Markdown(f'''
### 🎯 Groundedness Evaluation

**Context:** {sample['context']}

| Metric | Score | Pass/Fail |
|--------|-------|-----------|  
| **Groundedness** | {groundedness_result.get('groundedness', 'N/A')} | {groundedness_result.get('groundedness_result', 'N/A')} |

**Reason:** {groundedness_result.get('groundedness_reason', 'N/A')}
'''))
# Out:
# ### 🎯 Groundedness Evaluation
#
# **Context:** Mars has the largest volcano in the solar system called Olympus Mons which is about 13.6 miles high.
#
# | Metric | Score | Pass/Fail |
# |--------|-------|-----------|
# | **Groundedness** | 5.0 | pass |
#
# **Reason:** The response fully and accurately answers the question using all relevant details from the context without adding incorrect or unrelated information.

# %% [markdown]
# ## Step 12: Similarity Evaluator
#
# How similar is the response to the expected ground truth?

# %%
from azure.ai.evaluation import SimilarityEvaluator

similarity_eval = SimilarityEvaluator(model_config)

similarity_result = similarity_eval(
    query=sample['query'],
    response=sample['response'],
    ground_truth=sample['ground_truth']
)

display(Markdown(f'''
### 🎯 Similarity Evaluation

**Ground Truth:** {sample['ground_truth']}

**Response:** {sample['response'][:200]}...

| Metric | Score |
|--------|-------|
| **Similarity** | {similarity_result.get('similarity', 'N/A')} |
'''))
# Out:
# ### 🎯 Similarity Evaluation
#
# **Ground Truth:** Olympus Mons on Mars is the largest volcano in the solar system, about 13.6 miles high.
#
# **Response:** The largest volcano in the solar system is Olympus Mons on Mars. It stands about 13.6 miles (22 kilometers) high, making it the tallest volcano known in the solar system. (Source: fact-010)...
#
# | Metric | Score |
# |--------|-------|
# | **Similarity** | 5.0 |

# %% [markdown]
# ---
# # Part 3: Custom Evaluator
#
# Create your own evaluator for domain-specific requirements.

# %% [markdown]
# ## Step 13: Create a Custom Answer Length Evaluator

# %%
class AnswerLengthEvaluator:
    """Custom evaluator that checks if the answer is within an acceptable length range."""
    
    def __init__(self, min_length: int = 50, max_length: int = 500):
        self.min_length = min_length
        self.max_length = max_length
    
    def __call__(self, *, response: str, **kwargs):
        length = len(response)
        in_range = self.min_length <= length <= self.max_length
        
        return {
            "answer_length": length,
            "length_in_range": 1 if in_range else 0,
            "length_reason": f"Response has {length} characters. {'✅ Within range' if in_range else '❌ Outside range'} ({self.min_length}-{self.max_length})."
        }

# Test custom evaluator
answer_length_eval = AnswerLengthEvaluator(min_length=50, max_length=1000)
length_result = answer_length_eval(response=sample['response'])

display(Markdown(f'''
### 🎯 Custom Evaluator: Answer Length

| Metric | Value |
|--------|-------|
| **Length** | {length_result['answer_length']} characters |
| **In Range** | {"✅ Yes" if length_result['length_in_range'] else "❌ No"} |

**Reason:** {length_result['length_reason']}
'''))
# Out:
# ### 🎯 Custom Evaluator: Answer Length
#
# | Metric | Value |
# |--------|-------|
# | **Length** | 189 characters |
# | **In Range** | ✅ Yes |
#
# **Reason:** Response has 189 characters. ✅ Within range (50-1000).

# %% [markdown]
# ## Step 14: Create a Citation Check Evaluator
#
# Since our agent should cite sources, let's check for citations.

# %%
import re

class CitationEvaluator:
    """Custom evaluator that checks if the response contains citations."""
    
    def __call__(self, *, response: str, **kwargs):
        # Look for citation patterns (brackets, source mentions, etc.)
        citation_patterns = [
            r'\[\d+\]',           # [1], [2], etc.
            r'\[source\]',         # [source]
            r'according to',       # "according to..."
            r'based on',           # "based on..."
            r'from the',           # "from the knowledge base"
            r'knowledge base',     # direct mention
            r'space fact',         # mentions source
        ]
        
        has_citation = any(re.search(pattern, response.lower()) for pattern in citation_patterns)
        
        return {
            "has_citation": 1 if has_citation else 0,
            "citation_reason": "Response contains citation/source reference." if has_citation else "No citation found in response."
        }

# Test citation evaluator
citation_eval = CitationEvaluator()
citation_result = citation_eval(response=sample['response'])

display(Markdown(f'''
### 🎯 Custom Evaluator: Citation Check

| Metric | Value |
|--------|-------|
| **Has Citation** | {"✅ Yes" if citation_result['has_citation'] else "❌ No"} |

**Reason:** {citation_result['citation_reason']}
'''))
# Out:
# ### 🎯 Custom Evaluator: Citation Check
#
# | Metric | Value |
# |--------|-------|
# | **Has Citation** | ❌ No |
#
# **Reason:** No citation found in response.

# %% [markdown]
# ---
# # Part 4: Batch Evaluation with evaluate()
#
# Now let's run all evaluators on the entire test dataset!

# %% [markdown]
# ## Step 15: Run Batch Evaluation

# %%
from azure.ai.evaluation import evaluate

print("🚀 Running batch evaluation on test dataset...")
print("   This may take a minute...\n")

result = evaluate(
    data="test_data.jsonl",
    evaluators={
        "coherence": coherence_eval,
        "fluency": fluency_eval,
        "relevance": relevance_eval,
        "groundedness": groundedness_eval,
        "similarity": similarity_eval,
        "answer_length": answer_length_eval,
        "citation": citation_eval
    },
    evaluator_config={
        "groundedness": {
            "column_mapping": {
                "query": "${data.query}",
                "context": "${data.context}",
                "response": "${data.response}"
            }
        },
        "similarity": {
            "column_mapping": {
                "query": "${data.query}",
                "response": "${data.response}",
                "ground_truth": "${data.ground_truth}"
            }
        }
    },
    output_path="./evaluation_results.json",
    _use_pf_client=False  # Disable promptflow multiprocessing (fixes fork issues in containers/notebooks)
)

print("✅ Batch evaluation complete!")
# Out:
# 🚀 Running batch evaluation on test dataset...
#    This may take a minute...
#
# 2026-01-27 23:57:04 +0100   26604 execution.bulk     INFO     Finished 2 / 6 lines.
# 2026-01-27 23:57:04 +0100   27680 execution.bulk     INFO     Finished 5 / 6 lines.
# 2026-01-27 23:57:04 +0100   26604 execution.bulk     INFO     Average execution time for completed lines: 0.0 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2026-01-27 23:57:04 +0100   27680 execution.bulk     INFO     Average execution time for completed lines: 0.0 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2026-01-27 23:57:04 +0100   26604 execution.bulk     INFO     Finished 6 / 6 lines.
# 2026-01-27 23:57:04 +0100   26604 execution.bulk     INFO     Average execution time for completed lines: 0.0 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2026-01-27 23:57:04 +0100   27680 execution.bulk     INFO     Finished 6 / 6 lines.
# 2026-01-27 23:57:04 +0100   27680 execution.bulk     INFO     Average execution time for completed lines: 0.0 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "answer_length_20260127_225704_573761"
# Run status: "Completed"
# Start time: "2026-01-27 22:57:04.573761+00:00"
# Duration: "0:00:01.011739"
#
# ======= Run Summary =======
#
# Run name: "citation_20260127_225704_574586"
# Run status: "Completed"
# Start time: "2026-01-27 22:57:04.574586+00:00"
# Duration: "0:00:01.011220"
#
# 2026-01-27 23:57:09 +0100   48016 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 6.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   55872 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 8 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 8.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 8 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   28956 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 6.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   89680 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 6.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   48016 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 11 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 11.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 11 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   28956 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 6.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   55872 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 11 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 11.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 11 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   89680 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 6.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   48016 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 6.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   55872 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 8 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 8.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 8 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   28956 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 6.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   48016 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 8 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 8.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 8 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   89680 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 6.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   28956 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 8 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 8.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 8 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   55872 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 10 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 10.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 10 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   89680 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 6.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   48016 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 6.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   48016 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 6.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   89680 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 6.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 6 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   55872 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 13 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 13.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 13 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:57:09 +0100   28956 azure.ai.evaluation._legacy.prompty._prompty WARNING  [0/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 32 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 32.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 9 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:58:01 +0100   28956 execution.bulk     INFO     Finished 5 / 6 lines.
# 2026-01-27 23:58:01 +0100   28956 execution.bulk     INFO     Average execution time for completed lines: 11.35 seconds. Estimated time for incomplete lines: 11.35 seconds.
# 2026-01-27 23:58:01 +0100   55872 azure.ai.evaluation._legacy.prompty._prompty WARNING  [5/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 9 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 9.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 9 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:58:05 +0100   48016 azure.ai.evaluation._legacy.prompty._prompty WARNING  [5/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 5 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 5.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the call rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 5 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:58:10 +0100   28956 execution.bulk     INFO     Finished 6 / 6 lines.
# 2026-01-27 23:58:10 +0100   28956 execution.bulk     INFO     Average execution time for completed lines: 11.04 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2026-01-27 23:58:10 +0100   55872 azure.ai.evaluation._legacy.prompty._prompty WARNING  [6/10] AsyncAzureOpenAI request failed. RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 38 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}. Retrying in 38.000000 seconds.
# Traceback (most recent call last):
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\prompty\_prompty.py", line 383, in _send_with_retries
#     response = await client.chat.completions.create(**params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\azure\ai\evaluation\_legacy\_batch_engine\_openai_injector.py", line 50, in async_wrapper
#     result: _WithUsage = await method(*args, **kwargs)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 2678, in create
#     return await self._post(
#            ^^^^^^^^^^^^^^^^^
#     ...<49 lines>...
#     )
#     ^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1797, in post
#     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\repo\AI-Engineer-Zero-to-Hero\.venv\Lib\site-packages\openai\_base_client.py", line 1597, in request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'code': 'RateLimitReached', 'message': 'Your requests to gpt-4.1-mini for gpt-4.1-mini in East US 2 have exceeded the token rate limit for your current AIServices S0 pricing tier. This request was for ChatCompletions_Create under Azure OpenAI API version 2024-10-21. Please retry after 38 seconds. To increase your default rate limit, visit: https://aka.ms/oai/quotaincrease.'}}
# 2026-01-27 23:58:11 +0100   55872 execution.bulk     INFO     Finished 3 / 6 lines.
# 2026-01-27 23:58:11 +0100   55872 execution.bulk     INFO     Average execution time for completed lines: 22.22 seconds. Estimated time for incomplete lines: 66.66 seconds.
# 2026-01-27 23:58:11 +0100   55872 execution.bulk     INFO     Finished 4 / 6 lines.
# 2026-01-27 23:58:11 +0100   55872 execution.bulk     INFO     Average execution time for completed lines: 16.71 seconds. Estimated time for incomplete lines: 33.42 seconds.
# ======= Run Summary =======
#
# Run name: "similarity_20260127_225704_570636"
# Run status: "Completed"
# Start time: "2026-01-27 22:57:04.570636+00:00"
# Duration: "0:01:06.936768"
#
# 2026-01-27 23:58:11 +0100   55872 execution.bulk     INFO     Finished 5 / 6 lines.
# 2026-01-27 23:58:11 +0100   55872 execution.bulk     INFO     Average execution time for completed lines: 13.47 seconds. Estimated time for incomplete lines: 13.47 seconds.
# 2026-01-27 23:58:12 +0100   89680 execution.bulk     INFO     Finished 2 / 6 lines.
# 2026-01-27 23:58:12 +0100   89680 execution.bulk     INFO     Average execution time for completed lines: 33.83 seconds. Estimated time for incomplete lines: 135.32 seconds.
# 2026-01-27 23:58:12 +0100   48016 execution.bulk     INFO     Finished 4 / 6 lines.
# 2026-01-27 23:58:12 +0100   48016 execution.bulk     INFO     Average execution time for completed lines: 17.03 seconds. Estimated time for incomplete lines: 34.06 seconds.
# 2026-01-27 23:58:12 +0100   89680 execution.bulk     INFO     Finished 3 / 6 lines.
# 2026-01-27 23:58:12 +0100   89680 execution.bulk     INFO     Average execution time for completed lines: 22.71 seconds. Estimated time for incomplete lines: 68.13 seconds.
# 2026-01-27 23:58:12 +0100   48016 execution.bulk     INFO     Finished 5 / 6 lines.
# 2026-01-27 23:58:12 +0100   48016 execution.bulk     INFO     Average execution time for completed lines: 13.64 seconds. Estimated time for incomplete lines: 13.64 seconds.
# 2026-01-27 23:58:12 +0100   89680 execution.bulk     INFO     Finished 4 / 6 lines.
# 2026-01-27 23:58:12 +0100   89680 execution.bulk     INFO     Average execution time for completed lines: 17.08 seconds. Estimated time for incomplete lines: 34.16 seconds.
# 2026-01-27 23:58:12 +0100   48016 execution.bulk     INFO     Finished 6 / 6 lines.
# 2026-01-27 23:58:12 +0100   48016 execution.bulk     INFO     Average execution time for completed lines: 11.39 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2026-01-27 23:58:12 +0100   89680 execution.bulk     INFO     Finished 5 / 6 lines.
# 2026-01-27 23:58:12 +0100   89680 execution.bulk     INFO     Average execution time for completed lines: 13.67 seconds. Estimated time for incomplete lines: 13.67 seconds.
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# ======= Run Summary =======
#
# Run name: "coherence_20260127_225704_559210"
# Run status: "Completed"
# Start time: "2026-01-27 22:57:04.559210+00:00"
# Duration: "0:01:08.967742"
#
# 2026-01-27 23:58:13 +0100   89680 execution.bulk     INFO     Finished 6 / 6 lines.
# 2026-01-27 23:58:13 +0100   89680 execution.bulk     INFO     Average execution time for completed lines: 11.55 seconds. Estimated time for incomplete lines: 0.0 seconds.
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# ======= Run Summary =======
#
# Run name: "fluency_20260127_225704_557008"
# Run status: "Completed"
# Start time: "2026-01-27 22:57:04.557008+00:00"
# Duration: "0:01:09.985060"
#
# 2026-01-27 23:58:50 +0100   55872 execution.bulk     INFO     Finished 6 / 6 lines.
# 2026-01-27 23:58:50 +0100   55872 execution.bulk     INFO     Average execution time for completed lines: 17.66 seconds. Estimated time for incomplete lines: 0.0 seconds.
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# ======= Run Summary =======
#
# Run name: "relevance_20260127_225704_563902"
# Run status: "Completed"
# Start time: "2026-01-27 22:57:04.563902+00:00"
# Duration: "0:01:46.283316"
#
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "coherence": {
#         "status": "Completed",
#         "duration": "0:01:08.967742",
#         "completed_lines": 6,
#         "failed_lines": 0,
#         "log_path": null,
#         "error_message": null,
#         "error_code": null
#     },
#     "fluency": {
#         "status": "Completed",
#         "duration": "0:01:09.985060",
#         "completed_lines": 6,
#         "failed_lines": 0,
#         "log_path": null,
#         "error_message": null,
#         "error_code": null
#     },
#     "relevance": {
#         "status": "Completed",
#         "duration": "0:01:46.283316",
#         "completed_lines": 6,
#         "failed_lines": 0,
#         "log_path": null,
#         "error_message": null,
#         "error_code": null
#     },
#     "groundedness": {
#         "status": "Completed",
#         "duration": "0:00:08.421505",
#         "completed_lines": 6,
#         "failed_lines": 0,
#         "log_path": null,
#         "error_message": null,
#         "error_code": null
#     },
#     "similarity": {
#         "status": "Completed",
#         "duration": "0:01:06.936768",
#         "completed_lines": 6,
#         "failed_lines": 0,
#         "log_path": null,
#         "error_message": null,
#         "error_code": null
#     },
#     "answer_length": {
#         "status": "Completed",
#         "duration": "0:00:01.011739",
#         "completed_lines": 6,
#         "failed_lines": 0,
#         "log_path": null,
#         "error_message": null,
#         "error_code": null
#     },
#     "citation": {
#         "status": "Completed",
#         "duration": "0:00:01.011220",
#         "completed_lines": 6,
#         "failed_lines": 0,
#         "log_path": null,
#         "error_message": null,
#         "error_code": null
#     }
# }
#
# ====================================================
#
# Evaluation results saved to "C:\repo\AI-Engineer-Zero-to-Hero\16-evaluation\evaluation_results.json".
#
# ✅ Batch evaluation complete!
# c:\repo\AI-Engineer-Zero-to-Hero\16-evaluation\evaluation_helpers.py:99: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = df.style.applymap(highlight_scores, subset=score_columns).hide(axis='index')
# 📊 F1 Scores (word overlap with ground truth):
# ==================================================
# Query 1: F1 = 0.667
# Query 2: F1 = 0.588
# Query 3: F1 = 0.393
# Query 4: F1 = 1.000
# Query 5: F1 = 0.606
# Query 6: F1 = 0.630
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\haozhang2\AppData\Roaming\nltk_data...
# 📊 BLEU Scores:
# ==================================================
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     C:\Users\haozhang2\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping misc\perluniprops.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\haozhang2\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\haozhang2\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# Query 1: BLEU = 0.219
# Query 2: BLEU = 0.342
# Query 3: BLEU = 0.112
# Query 4: BLEU = 0.783
# Query 5: BLEU = 0.217
# Query 6: BLEU = 0.407
# 💬 Running multi-turn conversation...
# Turn 1: What is the largest volcano in the solar system?
# Turn 2: How high is it?
#
# ✅ Conversation recorded

# %% [markdown]
# ## Step 16: View Aggregate Metrics

# %%
from evaluation_helpers import display_metrics_summary

# Display formatted metrics
display_metrics_summary(result['metrics'])
# Out:
# ### 📊 Aggregate Metrics Summary
# #### Quality Metrics
# <style type="text/css">
# </style>
# <table id="T_aa70e">
#   <thead>
#     <tr>
#       <th id="T_aa70e_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_aa70e_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aa70e_row0_col0" class="data row0 col0" >coherence.coherence</td>
#       <td id="T_aa70e_row0_col1" class="data row0 col1" >4.17</td>
#     </tr>
#     <tr>
#       <td id="T_aa70e_row1_col0" class="data row1 col0" >coherence.gpt_coherence</td>
#       <td id="T_aa70e_row1_col1" class="data row1 col1" >4.17</td>
#     </tr>
#     <tr>
#       <td id="T_aa70e_row2_col0" class="data row2 col0" >coherence.coherence_threshold</td>
#       <td id="T_aa70e_row2_col1" class="data row2 col1" >3.00</td>
#     </tr>
#     <tr>
#       <td id="T_aa70e_row3_col0" class="data row3 col0" >fluency.fluency</td>
#       <td id="T_aa70e_row3_col1" class="data row3 col1" >3.33</td>
#     </tr>
#     <tr>
#       <td id="T_aa70e_row4_col0" class="data row4 col0" >fluency.gpt_fluency</td>
#       <td id="T_aa70e_row4_col1" class="data row4 col1" >3.33</td>
#     </tr>
#     <tr>
#       <td id="T_aa70e_row5_col0" class="data row5 col0" >fluency.fluency_threshold</td>
#       <td id="T_aa70e_row5_col1" class="data row5 col1" >3.00</td>
#     </tr>
#     <tr>
#       <td id="T_aa70e_row6_col0" class="data row6 col0" >relevance.relevance</td>
#       <td id="T_aa70e_row6_col1" class="data row6 col1" >4.83</td>
#     </tr>
#     <tr>
#       <td id="T_aa70e_row7_col0" class="data row7 col0" >relevance.gpt_relevance</td>
#       <td id="T_aa70e_row7_col1" class="data row7 col1" >4.83</td>
#     </tr>
#     <tr>
#       <td id="T_aa70e_row8_col0" class="data row8 col0" >relevance.relevance_threshold</td>
#       <td id="T_aa70e_row8_col1" class="data row8 col1" >3.00</td>
#     </tr>
#     <tr>
#       <td id="T_aa70e_row9_col0" class="data row9 col0" >coherence.binary_aggregate</td>
#       <td id="T_aa70e_row9_col1" class="data row9 col1" >1.00</td>
#     </tr>
#     <tr>
#       <td id="T_aa70e_row10_col0" class="data row10 col0" >fluency.binary_aggregate</td>
#       <td id="T_aa70e_row10_col1" class="data row10 col1" >1.00</td>
#     </tr>
#     <tr>
#       <td id="T_aa70e_row11_col0" class="data row11 col0" >relevance.binary_aggregate</td>
#       <td id="T_aa70e_row11_col1" class="data row11 col1" >1.00</td>
#     </tr>
#   </tbody>
# </table>
# #### RAG & Similarity Metrics
# <style type="text/css">
# </style>
# <table id="T_76634">
#   <thead>
#     <tr>
#       <th id="T_76634_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_76634_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_76634_row0_col0" class="data row0 col0" >groundedness.groundedness</td>
#       <td id="T_76634_row0_col1" class="data row0 col1" >5.00</td>
#     </tr>
#     <tr>
#       <td id="T_76634_row1_col0" class="data row1 col0" >groundedness.gpt_groundedness</td>
#       <td id="T_76634_row1_col1" class="data row1 col1" >5.00</td>
#     </tr>
#     <tr>
#       <td id="T_76634_row2_col0" class="data row2 col0" >groundedness.groundedness_threshold</td>
#       <td id="T_76634_row2_col1" class="data row2 col1" >3.00</td>
#     </tr>
#     <tr>
#       <td id="T_76634_row3_col0" class="data row3 col0" >similarity.similarity</td>
#       <td id="T_76634_row3_col1" class="data row3 col1" >5.00</td>
#     </tr>
#     <tr>
#       <td id="T_76634_row4_col0" class="data row4 col0" >similarity.gpt_similarity</td>
#       <td id="T_76634_row4_col1" class="data row4 col1" >5.00</td>
#     </tr>
#     <tr>
#       <td id="T_76634_row5_col0" class="data row5 col0" >similarity.similarity_threshold</td>
#       <td id="T_76634_row5_col1" class="data row5 col1" >3.00</td>
#     </tr>
#     <tr>
#       <td id="T_76634_row6_col0" class="data row6 col0" >groundedness.binary_aggregate</td>
#       <td id="T_76634_row6_col1" class="data row6 col1" >1.00</td>
#     </tr>
#     <tr>
#       <td id="T_76634_row7_col0" class="data row7 col0" >similarity.binary_aggregate</td>
#       <td id="T_76634_row7_col1" class="data row7 col1" >1.00</td>
#     </tr>
#   </tbody>
# </table>
# #### Custom Metrics
# <style type="text/css">
# </style>
# <table id="T_9df03">
#   <thead>
#     <tr>
#       <th id="T_9df03_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_9df03_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9df03_row0_col0" class="data row0 col0" >answer_length.answer_length</td>
#       <td id="T_9df03_row0_col1" class="data row0 col1" >203.83</td>
#     </tr>
#     <tr>
#       <td id="T_9df03_row1_col0" class="data row1 col0" >answer_length.length_in_range</td>
#       <td id="T_9df03_row1_col1" class="data row1 col1" >1.00</td>
#     </tr>
#     <tr>
#       <td id="T_9df03_row2_col0" class="data row2 col0" >citation.has_citation</td>
#       <td id="T_9df03_row2_col1" class="data row2 col1" >0.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 17: View Row-Level Results

# %%
from evaluation_helpers import display_row_results

# Display row-level results as a table
display_row_results(result['rows'])
# Out:
# ### 📋 Row-Level Results
# <style type="text/css">
# #T_86352_row0_col2, #T_86352_row0_col4, #T_86352_row0_col5, #T_86352_row0_col6, #T_86352_row1_col2, #T_86352_row1_col4, #T_86352_row1_col5, #T_86352_row1_col6, #T_86352_row2_col2, #T_86352_row2_col3, #T_86352_row2_col4, #T_86352_row2_col5, #T_86352_row2_col6, #T_86352_row3_col2, #T_86352_row3_col4, #T_86352_row3_col5, #T_86352_row3_col6, #T_86352_row4_col2, #T_86352_row4_col4, #T_86352_row4_col5, #T_86352_row4_col6, #T_86352_row5_col2, #T_86352_row5_col3, #T_86352_row5_col4, #T_86352_row5_col5, #T_86352_row5_col6 {
#   background-color: #2e7d32;
#   color: #e8f5e9;
# }
# #T_86352_row0_col3, #T_86352_row1_col3, #T_86352_row3_col3, #T_86352_row4_col3 {
#   background-color: #f9a825;
#   color: #1a1a1a;
# }
# </style>
# <table id="T_86352">
#   <thead>
#     <tr>
#       <th id="T_86352_level0_col0" class="col_heading level0 col0" >#</th>
#       <th id="T_86352_level0_col1" class="col_heading level0 col1" >Query</th>
#       <th id="T_86352_level0_col2" class="col_heading level0 col2" >Coherence</th>
#       <th id="T_86352_level0_col3" class="col_heading level0 col3" >Fluency</th>
#       <th id="T_86352_level0_col4" class="col_heading level0 col4" >Relevance</th>
#       <th id="T_86352_level0_col5" class="col_heading level0 col5" >Groundedness</th>
#       <th id="T_86352_level0_col6" class="col_heading level0 col6" >Similarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_86352_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_86352_row0_col1" class="data row0 col1" >What is the largest volcano in the solar...</td>
#       <td id="T_86352_row0_col2" class="data row0 col2" >4.000000</td>
#       <td id="T_86352_row0_col3" class="data row0 col3" >3.000000</td>
#       <td id="T_86352_row0_col4" class="data row0 col4" >4.000000</td>
#       <td id="T_86352_row0_col5" class="data row0 col5" >5.000000</td>
#       <td id="T_86352_row0_col6" class="data row0 col6" >5.000000</td>
#     </tr>
#     <tr>
#       <td id="T_86352_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_86352_row1_col1" class="data row1 col1" >How long has Jupiter's Great Red Spot be...</td>
#       <td id="T_86352_row1_col2" class="data row1 col2" >4.000000</td>
#       <td id="T_86352_row1_col3" class="data row1 col3" >3.000000</td>
#       <td id="T_86352_row1_col4" class="data row1 col4" >5.000000</td>
#       <td id="T_86352_row1_col5" class="data row1 col5" >5.000000</td>
#       <td id="T_86352_row1_col6" class="data row1 col6" >5.000000</td>
#     </tr>
#     <tr>
#       <td id="T_86352_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_86352_row2_col1" class="data row2 col1" >Why is a day on Venus longer than its ye...</td>
#       <td id="T_86352_row2_col2" class="data row2 col2" >4.000000</td>
#       <td id="T_86352_row2_col3" class="data row2 col3" >4.000000</td>
#       <td id="T_86352_row2_col4" class="data row2 col4" >5.000000</td>
#       <td id="T_86352_row2_col5" class="data row2 col5" >5.000000</td>
#       <td id="T_86352_row2_col6" class="data row2 col6" >5.000000</td>
#     </tr>
#     <tr>
#       <td id="T_86352_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_86352_row3_col1" class="data row3 col1" >How much of the solar system's mass does...</td>
#       <td id="T_86352_row3_col2" class="data row3 col2" >4.000000</td>
#       <td id="T_86352_row3_col3" class="data row3 col3" >3.000000</td>
#       <td id="T_86352_row3_col4" class="data row3 col4" >5.000000</td>
#       <td id="T_86352_row3_col5" class="data row3 col5" >5.000000</td>
#       <td id="T_86352_row3_col6" class="data row3 col6" >5.000000</td>
#     </tr>
#     <tr>
#       <td id="T_86352_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_86352_row4_col1" class="data row4 col1" >How fast does the International Space St...</td>
#       <td id="T_86352_row4_col2" class="data row4 col2" >5.000000</td>
#       <td id="T_86352_row4_col3" class="data row4 col3" >3.000000</td>
#       <td id="T_86352_row4_col4" class="data row4 col4" >5.000000</td>
#       <td id="T_86352_row4_col5" class="data row4 col5" >5.000000</td>
#       <td id="T_86352_row4_col6" class="data row4 col6" >5.000000</td>
#     </tr>
#     <tr>
#       <td id="T_86352_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_86352_row5_col1" class="data row5 col1" >What happens to astronauts' height in sp...</td>
#       <td id="T_86352_row5_col2" class="data row5 col2" >4.000000</td>
#       <td id="T_86352_row5_col3" class="data row5 col3" >4.000000</td>
#       <td id="T_86352_row5_col4" class="data row5 col4" >5.000000</td>
#       <td id="T_86352_row5_col5" class="data row5 col5" >5.000000</td>
#       <td id="T_86352_row5_col6" class="data row5 col6" >5.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 18: Analyze Results

# %%
from evaluation_helpers import analyze_evaluation_results

# Detailed analysis with recommendations
analyze_evaluation_results(result)
# Out:
# ### 🔍 Evaluation Analysis
# #### Score Summary
# **Coherence:** 4.17/5 - ✅ Good
# **Fluency:** 3.33/5 - ⚠️ Needs improvement
# **Relevance:** 4.83/5 - ✅ Good
# **Groundedness:** 5.00/5 - ✅ Good
# **Similarity:** 5.00/5 - ✅ Good
# #### 💡 Recommendations
# - Work on natural language generation quality
# #### ⚠️ Queries with Lowest Scores
# - Query 1: "What is the largest volcano in the solar system?..." (avg: 4.33)
# - Query 2: "How long has Jupiter's Great Red Spot been active?..." (avg: 4.67)
# - Query 3: "Why is a day on Venus longer than its year?..." (avg: 4.67)

# %% [markdown]
# ---
# # Part 5: NLP Evaluators (No Model Required)
#
# These evaluators use mathematical formulas rather than AI models.

# %% [markdown]
# ## Step 19: F1 Score Evaluator
#
# Measures word overlap between response and ground truth.

# %%
from azure.ai.evaluation import F1ScoreEvaluator

f1_eval = F1ScoreEvaluator()

# Test on all samples
print("📊 F1 Scores (word overlap with ground truth):")
print("="*50)

for i, row in df_test.iterrows():
    f1_result = f1_eval(
        response=row['response'],
        ground_truth=row['ground_truth']
    )
    print(f"Query {i+1}: F1 = {f1_result.get('f1_score', 0):.3f}")

# %% [markdown]
# ## Step 20: BLEU Score Evaluator
#
# Standard machine translation metric.

# %%
from azure.ai.evaluation import BleuScoreEvaluator

bleu_eval = BleuScoreEvaluator()

print("📊 BLEU Scores:")
print("="*50)

for i, row in df_test.iterrows():
    bleu_result = bleu_eval(
        response=row['response'],
        ground_truth=row['ground_truth']
    )
    print(f"Query {i+1}: BLEU = {bleu_result.get('bleu_score', 0):.3f}")

# %% [markdown]
# ---
# # Part 6: Conversation Evaluation
#
# Evaluate multi-turn conversations with your agent.

# %% [markdown]
# ## Step 21: Evaluate a Multi-Turn Conversation

# %%
# Simulate a multi-turn conversation
print("💬 Running multi-turn conversation...")

q1 = "What is the largest volcano in the solar system?"
r1 = ask_space_expert(q1)
print(f"Turn 1: {q1}")

q2 = "How high is it?"
r2 = ask_space_expert(q2)
print(f"Turn 2: {q2}")

# Format as conversation
conversation = {
    "messages": [
        {"content": q1, "role": "user"},
        {"content": r1, "role": "assistant", "context": "Mars has the largest volcano in the solar system called Olympus Mons which is about 13.6 miles high."},
        {"content": q2, "role": "user"},
        {"content": r2, "role": "assistant", "context": "Olympus Mons is about 13.6 miles (22 km) high."}
    ]
}

print("\n✅ Conversation recorded")

# %%
# Evaluate the conversation
groundedness_conv = groundedness_eval(conversation=conversation)

display(Markdown(f'''
### 🎯 Conversation Groundedness Evaluation

**Overall Score:** {groundedness_conv.get('groundedness', 'N/A')}

**Per-Turn Scores:**
| Turn | Score | Result |
|------|-------|--------|
| Turn 1 | {groundedness_conv.get('evaluation_per_turn', {}).get('groundedness', [None, None])[0]} | {groundedness_conv.get('evaluation_per_turn', {}).get('groundedness_result', ['N/A', 'N/A'])[0]} |
| Turn 2 | {groundedness_conv.get('evaluation_per_turn', {}).get('groundedness', [None, None])[1]} | {groundedness_conv.get('evaluation_per_turn', {}).get('groundedness_result', ['N/A', 'N/A'])[1]} |
'''))
# Out:
# ### 🎯 Conversation Groundedness Evaluation
#
# **Overall Score:** 3.0
#
# **Per-Turn Scores:**
# | Turn | Score | Result |
# |------|-------|--------|
# | Turn 1 | 5.0 | pass |
# | Turn 2 | 1.0 | fail |

# %% [markdown]
# ---
# ## 🎉 Summary
#
# You've learned how to evaluate your AI applications with the Azure AI Evaluation SDK!
#
# ### Evaluators Used
#
# | Category | Evaluators | Purpose |
# |----------|------------|---------|
# | **Quality** | Coherence, Fluency | Response readability |
# | **Relevance** | Relevance | Does it answer the question? |
# | **RAG** | Groundedness, Similarity | Factual accuracy, hallucination detection |
# | **NLP** | F1 Score, BLEU | Mathematical text similarity |
# | **Custom** | AnswerLength, Citation | Domain-specific requirements |
#
# ### Key Concepts
#
# - **Single-row evaluation** = Spot-check individual responses
# - **Batch evaluation** = Scale to entire test datasets
# - **Custom evaluators** = Add your own business logic
# - **Conversation mode** = Evaluate multi-turn interactions
# - **NLP evaluators** = No model needed for mathematical metrics
#
# ### Next Steps
#
# - Add **safety evaluators** for content moderation
# - Log results to **Foundry project** for tracking
# - Create **CI/CD pipelines** with evaluation gates
# - Build **custom evaluators** for your domain

# %% [markdown]
# ## Cleanup (Optional)

# %%
# Remove generated files
# import os
# os.remove('test_data.jsonl')
# os.remove('evaluation_results.json')
# print("🗑️ Cleanup complete")
